# %%
import argparse, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import imdb
from tensorflow.keras import models, layers, optimizers, losses, metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
# Out:
# /home/rmaia/miniconda3/envs/dim0494/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# constants and hyperparameters
MAX_WORD_INDEX = 10000

BATCH_SIZE = 128
NUM_EPOCHS = 20
LR = 0.001
BETA1 = 0.9
BETA2 = 0.999
EPSILON = 1.0e-8
DECAY = 0.0
VAL_PERC = 0.4

EMBEDDING_DIM = 64
DROPOUT_RATE = 0.5

# %%
# load database using Keras
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words = MAX_WORD_INDEX)

# %%
#  print some information on the data
max_seq_len_train = max([len(sequence) for sequence in train_data])
max_seq_len_test = max([len(sequence) for sequence in test_data])
min_seq_len_train = min([len(sequence) for sequence in train_data])
min_seq_len_test = min([len(sequence) for sequence in test_data])
print(f'Maximum train sequence length: {max_seq_len_train}')
print(f'Maximum test sequence length: {max_seq_len_test}')
print(f'Minimum train sequence length: {min_seq_len_train}')
print(f'Minimum test sequence length: {min_seq_len_test}')
# Out:
# Maximum train sequence length: 2494
# Maximum test sequence length: 2315
# Minimum train sequence length: 11
# Minimum test sequence length: 7

# %%
# randomly selects a sentence, look at the encoding and check its label
word_index = imdb.get_word_index()

ind = 33

reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

decoded_review = ' '.join([reverse_word_index.get(i-3, '?') for i in train_data[ind]])

print(f'REVIEW:\n {decoded_review}\n')
print(f'Encoded sequence of words:\n {train_data[ind]}\n')
print(f'Label: {train_labels[ind]}\n')
# Out:
# REVIEW:
#  ? i don't know what it is i find so endearing about this film but the first time i saw it i wanted to see how it ended i'm not a big fan of paul ? nor of war dramas but i was truly wondering just how and when ? would find his child all he knows is that the boy has green eyes truth be told i have not seen this movie in years nor has it been shown on tv in a while but this movie is somewhat of one man's odyssey after the pains of war ? shows a very sympathetic and heart warming portrayal of a man lost by his memories there is an underlying message in this movie that he is looking for the last shred of human morality in the aftermath of this war and the reality that he does confront why this movie is not yet on dvd or video is a mystery to me
#
# Encoded sequence of words:
#  [1, 13, 92, 124, 51, 12, 9, 13, 169, 38, 3308, 44, 14, 22, 21, 4, 86, 58, 13, 219, 12, 13, 473, 8, 67, 89, 12, 1054, 146, 24, 6, 194, 337, 7, 723, 2, 885, 7, 325, 3287, 21, 13, 16, 371, 1535, 43, 89, 5, 54, 2, 62, 169, 27, 506, 32, 29, 694, 9, 15, 4, 430, 47, 1419, 523, 882, 30, 579, 13, 28, 24, 110, 14, 20, 11, 153, 885, 47, 12, 77, 617, 23, 248, 11, 6, 137, 21, 14, 20, 9, 643, 7, 31, 1601, 6761, 103, 4, 7154, 7, 325, 2, 287, 6, 55, 2259, 5, 483, 4051, 1146, 7, 6, 132, 416, 34, 27, 1883, 50, 9, 35, 5029, 749, 11, 14, 20, 15, 29, 9, 267, 18, 4, 236, 7778, 7, 406, 3696, 11, 4, 7032, 7, 14, 325, 5, 4, 635, 15, 29, 127, 6275, 138, 14, 20, 9, 24, 246, 23, 288, 42, 374, 9, 6, 736, 8, 72]
#
# Label: 1

# %%
# pad sequences
X_train = keras.preprocessing.sequence.pad_sequences(train_data)
X_test = keras.preprocessing.sequence.pad_sequences(test_data)
print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
# Out:
# X_train shape: (25000, 2494)
# X_test shape: (25000, 2315)

# %%
# transform labels  into arrays
y_train = np.asarray(train_labels).astype('float32')
y_test  = np.asarray(test_labels).astype('float32')
print(f'y_train shape: {y_train.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# y_train shape: (25000,)
# y_test shape: (25000,)

# %%
# split training data into training and validation
nsamples = X_train.shape[0]
nval_samples = int(VAL_PERC * nsamples)
X_val = X_train[:nval_samples]
partial_X_train = X_train[nval_samples:]
y_val = y_train[:nval_samples]
partial_y_train = y_train[nval_samples:]
print(f'partial_X_train shape: {partial_X_train.shape}')
print(f'partial_y_train shape: {partial_y_train.shape}')
# Out:
# partial_X_train shape: (15000, 2494)
# partial_y_train shape: (15000,)

# %%
# build model
model = models.Sequential()
model.add(layers.Embedding(MAX_WORD_INDEX, EMBEDDING_DIM))
model.add(layers.Conv1D(filters=32, kernel_size=7, padding='valid', strides=1))
model.add(layers.LeakyReLU(0.2))
model.add(layers.Dropout(DROPOUT_RATE))
model.add(layers.MaxPool1D(5))
model.add(layers.Conv1D(filters=32, kernel_size=7, padding='valid', strides=1))
model.add(layers.LeakyReLU(0.2))
model.add(layers.Dropout(DROPOUT_RATE))
model.add(layers.GlobalMaxPooling1D())
model.add(layers.Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_40 (Embedding)    (None, None, 64)          640000
#
#  conv1d_71 (Conv1D)          (None, None, 32)          14368
#
#  leaky_re_lu_61 (LeakyReLU)  (None, None, 32)          0
#
#  dropout_5 (Dropout)         (None, None, 32)          0
#
#  max_pooling1d_57 (MaxPoolin  (None, None, 32)         0
#  g1D)
#
#  conv1d_72 (Conv1D)          (None, None, 32)          7200
#
#  leaky_re_lu_62 (LeakyReLU)  (None, None, 32)          0
#
#  dropout_6 (Dropout)         (None, None, 32)          0
#
#  global_max_pooling1d_8 (Glo  (None, 32)               0
#  balMaxPooling1D)
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 661,601
# Trainable params: 661,601
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# set optimizer
opt = optimizers.Adam(lr=LR,
                      beta_1=BETA1,
                      beta_2=BETA2,
                      epsilon=EPSILON,
                      decay=DECAY)

# set loss and metrics
loss = losses.binary_crossentropy
met = [metrics.binary_accuracy]

# compile model: optimization method, training criterion and metrics
model.compile(
    optimizer=opt,
    loss=loss,
    metrics=met
    )

# %%
# early stop
callbacks_list = [
    EarlyStopping(
        monitor='binary_accuracy',
        patience=10),
    ]

# %%
# train model
history = model.fit(partial_X_train,
                    partial_y_train,
                    epochs=NUM_EPOCHS,
                    batch_size=BATCH_SIZE,
                    shuffle=True,
                    validation_data=(X_val, y_val),
                    callbacks=callbacks_list,
                    verbose=1)
# Out:
# Epoch 1/20
# 118/118 [==============================] - 2s 18ms/step - loss: 0.6376 - binary_accuracy: 0.6201 - val_loss: 0.5414 - val_binary_accuracy: 0.8208
# Epoch 2/20
# 118/118 [==============================] - 2s 18ms/step - loss: 0.3179 - binary_accuracy: 0.8673 - val_loss: 0.4323 - val_binary_accuracy: 0.8648
# Epoch 3/20
# 118/118 [==============================] - 2s 18ms/step - loss: 0.1916 - binary_accuracy: 0.9265 - val_loss: 0.3806 - val_binary_accuracy: 0.8657
# Epoch 4/20
# 118/118 [==============================] - 2s 18ms/step - loss: 0.1239 - binary_accuracy: 0.9569 - val_loss: 0.3628 - val_binary_accuracy: 0.8528
# Epoch 5/20
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0795 - binary_accuracy: 0.9724 - val_loss: 0.3489 - val_binary_accuracy: 0.8495
# Epoch 6/20
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0455 - binary_accuracy: 0.9853 - val_loss: 0.3473 - val_binary_accuracy: 0.8494
# Epoch 7/20
# 118/118 [==============================] - 2s 20ms/step - loss: 0.0259 - binary_accuracy: 0.9929 - val_loss: 0.3529 - val_binary_accuracy: 0.8493
# Epoch 8/20
# 118/118 [==============================] - 2s 20ms/step - loss: 0.0160 - binary_accuracy: 0.9955 - val_loss: 0.3712 - val_binary_accuracy: 0.8474
# Epoch 9/20
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0107 - binary_accuracy: 0.9972 - val_loss: 0.3971 - val_binary_accuracy: 0.8438
# Epoch 10/20
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0090 - binary_accuracy: 0.9972 - val_loss: 0.4149 - val_binary_accuracy: 0.8427
# Epoch 11/20
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0133 - binary_accuracy: 0.9951 - val_loss: 0.4109 - val_binary_accuracy: 0.8462
# Epoch 12/20
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0214 - binary_accuracy: 0.9923 - val_loss: 0.4649 - val_binary_accuracy: 0.8345
# Epoch 13/20
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0218 - binary_accuracy: 0.9920 - val_loss: 0.4333 - val_binary_accuracy: 0.8445
# Epoch 14/20
# 118/118 [==============================] - 2s 19ms/step - loss: 0.0158 - binary_accuracy: 0.9945 - val_loss: 0.4476 - val_binary_accuracy: 0.8417
# Epoch 15/20
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0206 - binary_accuracy: 0.9923 - val_loss: 0.4688 - val_binary_accuracy: 0.8364
# Epoch 16/20
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0169 - binary_accuracy: 0.9936 - val_loss: 0.4449 - val_binary_accuracy: 0.8429
# Epoch 17/20
# 118/118 [==============================] - 2s 21ms/step - loss: 0.0118 - binary_accuracy: 0.9958 - val_loss: 0.4527 - val_binary_accuracy: 0.8469
# Epoch 18/20
# 118/118 [==============================] - 2s 20ms/step - loss: 0.0050 - binary_accuracy: 0.9985 - val_loss: 0.4703 - val_binary_accuracy: 0.8448
# Epoch 19/20
# 118/118 [==============================] - 3s 23ms/step - loss: 0.0039 - binary_accuracy: 0.9987 - val_loss: 0.4780 - val_binary_accuracy: 0.8440
# Epoch 20/20
# 118/118 [==============================] - 3s 22ms/step - loss: 0.0021 - binary_accuracy: 0.9995 - val_loss: 0.4821 - val_binary_accuracy: 0.8448

# %%
# learning curves
history_dict = history.history
history_dict.keys()

# losses
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

# accuracies
acc_values = history_dict['binary_accuracy']
val_acc_values = history_dict['val_binary_accuracy']

epochs = range(NUM_EPOCHS)

fig, (ax1, ax2) = plt.subplots(2,1, figsize=(10,10))

ax1.plot(epochs, loss_values, 'bo', label="Training Loss")
ax1.plot(epochs, val_loss_values, 'b', label="Validation Loss")
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss Value')
ax1.legend()

ax2.plot(epochs, acc_values, 'ro', label="Training Accuracy")
ax2.plot(epochs, val_acc_values, 'r', label="Validation Accuracy")
ax2.set_title('Training and Validation Accuraccy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.show()
